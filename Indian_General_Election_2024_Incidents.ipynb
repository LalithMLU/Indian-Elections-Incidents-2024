# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/drive/MyDrive/Indian General Election 2024 Incidents ex.xlsx')

# %%
df.head(5)
# Out:
#         Date              State Lokshabha Seat Name     Incident Description  \
# 0 2024-04-19            Manipur         Thamanpokpi               Gun Firing
# 1 2024-04-19            Manipur       Inner Manipur    Alleged Irregularties
# 2 2024-04-19  Arunachal Pradesh      Arunachal West  Violence and EVM damage
# 3 2024-04-26          Karnataka      Chamarajanagar             Voters Clash
# 4 2024-04-26          Rajasthan              Barmer          Booth Capturing
#
#               Action taken Location of Incident  \
# 0                Repolling                  NaN
# 1  Voting Station Shutdown              Thongju
# 2                Repolling     8 Polling Booths
# 3                Repolling                Hanur
# 4                Repolling         Dudhwa Khurd
#
#                              Coordinates  \
# 0                                    NaN
# 1  24.757850044919493, 93.93944606626353
# 2                                    NaN
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                     0
# State                    1
# Lokshabha Seat Name      0
# Incident Description     0
# Action taken            15
# Location of Incident    17
# Coordinates             23
# Source news article      3
# dtype: int64

# %%
df.head(30)
# Out:
#          Date              State            Lokshabha Seat Name  \
# 0  2024-04-19            Manipur                    Thamanpokpi
# 1  2024-04-19            Manipur                  Inner Manipur
# 2  2024-04-19  Arunachal Pradesh                 Arunachal West
# 3  2024-04-26          Karnataka                 Chamarajanagar
# 4  2024-04-26          Rajasthan                         Barmer
# 5  2024-04-26          Rajasthan                          Ajmer
# 6  2024-04-26      Uttar Pradesh                      Ghaziabad
# 7  2024-05-07             Gujrat                          Dahod
# 8  2024-05-07     Madhya Pradesh                         Bhopal
# 9  2024-05-07     Madhya Pradesh                          Betul
# 10 2024-05-07     Madhya Pradesh                          Harda
# 11 2024-05-07      Uttar Pradesh                        Sambhal
# 12 2024-05-07      Uttar Pradesh                      Firzobaad
# 13 2024-05-07      Uttar Pradesh                      Firzobaad
# ...

# %%
df['Action taken'].replace(np.NaN,'No Action Taken',inplace=True)

# %%
df.head(20)
# Out:
#          Date              State Lokshabha Seat Name  \
# 0  2024-04-19            Manipur         Thamanpokpi
# 1  2024-04-19            Manipur       Inner Manipur
# 2  2024-04-19  Arunachal Pradesh      Arunachal West
# 3  2024-04-26          Karnataka      Chamarajanagar
# 4  2024-04-26          Rajasthan              Barmer
# 5  2024-04-26          Rajasthan               Ajmer
# 6  2024-04-26      Uttar Pradesh           Ghaziabad
# 7  2024-05-07             Gujrat               Dahod
# 8  2024-05-07     Madhya Pradesh              Bhopal
# 9  2024-05-07     Madhya Pradesh               Betul
# 10 2024-05-07     Madhya Pradesh               Harda
# 11 2024-05-07      Uttar Pradesh             Sambhal
# 12 2024-05-07      Uttar Pradesh           Firzobaad
# 13 2024-05-07      Uttar Pradesh           Firzobaad
# 14 2024-05-07      Uttar Pradesh            Mainpuri
# 15 2024-05-07      Uttar Pradesh             Sambhal
# 16 2024-05-07      Uttar Pradesh           Moradabad
# ...

# %%
df['Location of Incident'].replace(np.NaN,'Unkown',inplace=True)

# %%
df['State'].replace(np.NaN,'Unkown',inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'State', 'Lokshabha Seat Name', 'Incident Description',
#        'Action taken', 'Location of Incident', 'Coordinates',
#        'Source news article'],
#       dtype='object')

# %%
df['Coordinates'].replace(np.NaN,0,inplace=True)

# %%
df['Source news article'].replace(np.NaN,'Small Incident',inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                    0
# State                   0
# Lokshabha Seat Name     0
# Incident Description    0
# Action taken            0
# Location of Incident    0
# Coordinates             0
# Source news article     0
# dtype: int64

# %%
df.describe()
# Out:
#                                 Date
# count                             39
# mean   2024-05-13 05:32:18.461538560
# min              2024-04-19 00:00:00
# 25%              2024-05-07 00:00:00
# 50%              2024-05-07 00:00:00
# 75%              2024-05-28 12:00:00
# max              2024-06-01 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  39 non-null     datetime64[ns]
#  1   State                 39 non-null     object
#  2   Lokshabha Seat Name   39 non-null     object
#  3   Incident Description  39 non-null     object
#  4   Action taken          39 non-null     object
#  5   Location of Incident  39 non-null     object
#  6   Coordinates           39 non-null     object
#  7   Source news article   39 non-null     object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 2.6+ KB

# %%
df.columns
# Out:
# Index(['Date', 'State', 'Lokshabha Seat Name', 'Incident Description',
#        'Action taken', 'Location of Incident', 'Coordinates',
#        'Source news article'],
#       dtype='object')

# %%
loi = df['Location of Incident'][df['Action taken']=='No Action Taken']

# %%
loi
# Out:
# 6                               Unkown
# 15                              Unkown
# 16                            Kundarki
# 17                            Shekhpur
# 18                              Kursra
# 21                              Unkown
# 23                              Unkown
# 25               Vivek Vardhini School
# 28                              Unkown
# 29                             Bhangur
# 30                              Unkown
# 35                        Sandeshkhali
# 36    Banimadhabpur F P Primary School
# 37                             Bhangar
# 38                              Unkown
# Name: Location of Incident, dtype: object

# %%
loi_gb = df.groupby('Location of Incident').agg({'Location of Incident':'count'})
loi_gb
# Out:
#                                   Location of Incident
# Location of Incident
# 8 Polling Booths                                     1
# Aliganj                                              1
# Asmoli                                               1
# Banimadhabpur F P Primary School                     1
# Berasia                                              1
# Bhangar                                              1
# Bhangur                                              1
# Deganga                                              1
# Dharmapuri                                           1
# Dudhwa Khurd                                         1
# Hanur                                                1
# Kakdwip                                              1
# Kundarki                                             1
# Kursra                                               1
# Malakpet                                             1
# Masuda                                               1
# ...

# %%
loi_A = df['Location of Incident'][df['Action taken']=='Arrested']

# %%
loi_A
# Out:
# 12     Unkown
# 13     Unkown
# 14     Unkown
# 20    Berasia
# Name: Location of Incident, dtype: object

# %%
at = df.groupby('Action taken').agg({'Action taken':'count'})

# %%
df.columns
# Out:
# Index(['Date', 'State', 'Lokshabha Seat Name', 'Incident Description',
#        'Action taken', 'Location of Incident', 'Coordinates',
#        'Source news article'],
#       dtype='object')

# %%
at
# Out:
#                                   Action taken
# Action taken
# Arrested                                     4
# Dismissed by district Megistrate             1
# Dismissed by police                          1
# Inquiry and no-repolling                     2
# Legal Case                                   4
# No Action Taken                             15
# Repolling                                   11
# Voting Station Shutdown                      1

# %%
pi = df.pivot(index='Incident Description',columns='Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-602a6dcb701c> in <cell line: 1>()
# ----> 1 pi = df.pivot(index='Incident Description',columns='Date')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, columns, index, values)
#    9023         from pandas.core.reshape.pivot import pivot
#    9024
# -> 9025         return pivot(self, index=index, columns=columns, values=values)
#    9026
#    9027     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot(data, columns, index, values)
#     551     # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552     # "Hashable"
# --> 553     result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     554     result.index.names = [
# ...

# %%
df['Date'].drop_duplicates(inplace=True)

# %%
df = pd.read_excel('/content/drive/MyDrive/Indian General Election 2024 Incidents ex.xlsx')

# %%
pi = df.pivot(index='Date',columns='Action taken')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-d3a869bbb918> in <cell line: 1>()
# ----> 1 pi = df.pivot(index='Date',columns='Action taken')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, columns, index, values)
#    9023         from pandas.core.reshape.pivot import pivot
#    9024
# -> 9025         return pivot(self, index=index, columns=columns, values=values)
#    9026
#    9027     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot(data, columns, index, values)
#     551     # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552     # "Hashable"
# --> 553     result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     554     result.index.names = [
# ...

# %%
df.set_index('Date',inplace=True)

# %%
pi = df.pivot(index='',columns='State')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-07845d2a3f11> in <cell line: 1>()
# ----> 1 pi = df.pivot(index='Action taken',columns='State')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, columns, index, values)
#    9023         from pandas.core.reshape.pivot import pivot
#    9024
# -> 9025         return pivot(self, index=index, columns=columns, values=values)
#    9026
#    9027     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot(data, columns, index, values)
#     551     # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552     # "Hashable"
# --> 553     result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     554     result.index.names = [
# ...

# %%
df.to_excel('/content/drive/MyDrive/Indian General Election 2024 Incidents(cleaned).xlsx',sheet_name='cleaned data')
